# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('cip_ctx_ctz_gen_multi_data.csv')
df2 = pd.read_csv('cip_ctx_ctz_gen_pheno.csv')

# %% [markdown]
# # Data set
#
# ### 1) Multi-data SNPs (single nucleotide polymorphism):
#
# Features:
#
# - prename: This is the isolate(sample) name.
# - The other 60k plus features are the position of SNPs
#
# Encoding:
# - A: Adenine = 1
# - G: Guanine = 2
# - C: Cytosine = 3
# - T: Thymine = 4
# - N: Null = 0
#
#
# ### 2) Phenotype:
#
# Features:
#
# - CTX: This is the isolate's response to the drug cefotaxime.
# - CTZ: This is the isolate's response to the drug ceftazidime
# - GEN: This is the isolate's response to the drug gentamicin
# - CIP: This is the isolate's response to the drug ciprofloxacin.
# - Prename: the name of the sample
#
# Encoding:
#
# - 0 = Susceptible,
# - 1 = Resistant

# %%
raw = pd.read_csv('ACTGN_input.csv')
raw
# Out:
#      Unnamed: 0              prename X393 X588 X747 X759 X774 X966 X1299  \
# 0             0         H100_S2_L001    G    A    G    T    C    C     C
# 1             1         H105_S3_L001    G    A    G    T    C    C     C
# 2             2         H108_S5_L001    G    A    G    T    C    C     N
# 3             3         H109_S2_L001    G    A    G    T    C    C     C
# 4             4         H113_S6_L001    N    N    G    T    C    C     C
# ..          ...                  ...  ...  ...  ...  ...  ...  ...   ...
# 804         804  wwRBK-17-0298-1_S42    N    N    G    T    C    C     N
# 805         805   wwRBK-17-075-1_S28    G    A    G    T    C    C     C
# 806         806   wwRBL-16-111-1_S16    G    N    N    N    C    N     C
# 807         807   wwRBL-17-004-1_S44    G    A    G    T    C    C     C
# 808         808    WWSurvcare043_S43    G    A    G    T    C    C     C
#
#     X1302  ... X4639956.3 X4640785.3 X4640908.3 X4640924.3 X4641031.3  \
# 0       C  ...          C          T          T          G          A
# 1       C  ...          C          T          T          G          A
# 2       N  ...          C          T          T          G          A
# 3       C  ...          C          T          T          G          A
# 4       C  ...          C          T          N          N          G
# ..    ...  ...        ...        ...        ...        ...        ...
# 804     N  ...          C          T          N          N          G
# 805     C  ...          C          T          T          G          A
# 806     C  ...          C          T          N          N          N
# 807     C  ...          C          T          T          G          A
# 808     C  ...          C          T          T          G          A
#
#     X4641131.3 X4641217.3 X4641296.3 X4641439.3 X4641440.3
# 0            C          A          C          C          A
# 1            C          A          C          C          A
# 2            C          A          C          C          A
# 3            C          A          C          C          A
# 4            C          A          C          C          A
# ..         ...        ...        ...        ...        ...
# 804          C          A          C          C          A
# 805          C          A          C          C          A
# 806          C          N          N          N          N
# 807          C          A          C          C          A
# 808          C          A          C          C          A
#
# [809 rows x 60938 columns]

# %%
data = raw.replace({'A':1, 'G':2, 'C':3, 'T':4, 'N':0})
data
# Out:
#                  prename  X393  X588  X747  X759  X774  X966  X1299  X1302  \
# 0           H100_S2_L001     2     1     2     4     3     3      3      3
# 1           H105_S3_L001     2     1     2     4     3     3      3      3
# 2           H108_S5_L001     2     1     2     4     3     3      0      0
# 3           H109_S2_L001     2     1     2     4     3     3      3      3
# 4           H113_S6_L001     0     0     2     4     3     3      3      3
# ..                   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 804  wwRBK-17-0298-1_S42     0     0     2     4     3     3      0      0
# 805   wwRBK-17-075-1_S28     2     1     2     4     3     3      3      3
# 806   wwRBL-16-111-1_S16     2     0     0     0     3     0      3      3
# 807   wwRBL-17-004-1_S44     2     1     2     4     3     3      3      3
# 808    WWSurvcare043_S43     2     1     2     4     3     3      3      3
#
#      X1407  ...  X4639956.3  X4640785.3  X4640908.3  X4640924.3  X4641031.3  \
# 0        4  ...           3           4           4           2           1
# 1        4  ...           3           4           4           2           1
# 2        4  ...           3           4           4           2           1
# 3        4  ...           3           4           4           2           1
# 4        4  ...           3           4           0           0           2
# ..     ...  ...         ...         ...         ...         ...         ...
# 804      4  ...           3           4           0           0           2
# 805      4  ...           3           4           4           2           1
# 806      4  ...           3           4           0           0           0
# 807      4  ...           3           4           4           2           1
# 808      4  ...           3           4           4           2           1
#
#      X4641131.3  X4641217.3  X4641296.3  X4641439.3  X4641440.3
# 0             3           1           3           3           1
# 1             3           1           3           3           1
# 2             3           1           3           3           1
# 3             3           1           3           3           1
# 4             3           1           3           3           1
# ..          ...         ...         ...         ...         ...
# 804           3           1           3           3           1
# 805           3           1           3           3           1
# 806           3           0           0           0           0
# 807           3           1           3           3           1
# 808           3           1           3           3           1
#
# [809 rows x 60937 columns]

# %%
df2
# Out:
#                  prename  CIP  CTX  CTZ  GEN
# 0           H100_S2_L001    0    1    0    0
# 1           H105_S3_L001    1    1    0    0
# 2           H108_S5_L001    0    1    0    0
# 3           H109_S2_L001    0    1    0    0
# 4           H113_S6_L001    1    1    0    0
# ..                   ...  ...  ...  ...  ...
# 804  wwRBK-17-0298-1_S42    1    1    1    0
# 805   wwRBK-17-075-1_S28    1    1    1    1
# 806   wwRBL-16-111-1_S16    1    1    1    0
# 807   wwRBL-17-004-1_S44    1    1    1    1
# 808    WWSurvcare043_S43    1    1    1    0
#
# [809 rows x 5 columns]
